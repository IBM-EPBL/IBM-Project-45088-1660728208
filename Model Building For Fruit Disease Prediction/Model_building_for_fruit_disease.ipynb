# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
test_datagen=ImageDataGenerator(rescale=1)

# %%
x_train=train_datagen.flow_from_directory(r'/content/drive/MyDrive/DATA COLLECTION/Dataset Plant Disease/fruit-dataset',target_size=(128,128),batch_size=2,class_mode='categorical')
x_test=test_datagen.flow_from_directory(r'/content/drive/MyDrive/DATA COLLECTION/Dataset Plant Disease/fruit-dataset',target_size=(128,128),batch_size=2,class_mode='categorical')
# Out:
# Found 2261 images belonging to 1 classes.
# Found 2261 images belonging to 1 classes.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #1. Import the libraries

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten

# %% [markdown]
# #2. initializing the model

# %%
model=Sequential()

# %% [markdown]
# #3. Add CNN layers

# %%
model.add(Convolution2D(32,(3,3),input_shape=(128,128,3),activation='relu'))

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.add(Flatten())

# %% [markdown]
# #4. Add dense layer

# %%
model.add(Dense(units=40,kernel_initializer='uniform',activation='relu'))

# %%
model.add(Dense(units=20,kernel_initializer='random_uniform',activation='relu'))

# %%
model.add(Dense(units=6,kernel_initializer='random_uniform',activation='softmax'))

# %% [markdown]
# #5. Train and save the model

# %%
model.compile(loss='categorical_crossentropy',optimizer="adam",metrics=["accuracy"])

# %%
model.fit(x_train,steps_per_epoch=89,epochs=20,validation_data=x_test,validation_steps=27)
# Out:
# Epoch 1/20
# 89/89 [==============================] - 75s 829ms/step - loss: 221.5738 - accuracy: 0.0562 - val_loss: 80412.2578 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 89/89 [==============================] - 66s 742ms/step - loss: 4370.2451 - accuracy: 0.1685 - val_loss: 1995715.5000 - val_accuracy: 1.0000
# Epoch 3/20
# 89/89 [==============================] - 54s 606ms/step - loss: 24277.2227 - accuracy: 0.1685 - val_loss: 21028272.0000 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 89/89 [==============================] - 48s 545ms/step - loss: 116968.1016 - accuracy: 0.1685 - val_loss: 76103736.0000 - val_accuracy: 1.0000
# Epoch 5/20
# 89/89 [==============================] - 38s 428ms/step - loss: 350920.3750 - accuracy: 0.1685 - val_loss: 93514336.0000 - val_accuracy: 1.0000
# Epoch 6/20
# 89/89 [==============================] - 37s 422ms/step - loss: 556902.6250 - accuracy: 0.1685 - val_loss: 92949088.0000 - val_accuracy: 0.0000e+00
# Epoch 7/20
# ...

# %%
model.save('fruit.h5')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  flatten (Flatten)           (None, 127008)            0
#
#  dense (Dense)               (None, 40)                5080360
#
#  dense_1 (Dense)             (None, 20)                820
#
#  dense_2 (Dense)             (None, 6)                 126
#
#  dense_3 (Dense)             (None, 40)                280
#
#  dense_4 (Dense)             (None, 20)                820
#
#  dense_5 (Dense)             (None, 6)                 126
#
# ...
# Total params: 5,083,428
# Trainable params: 5,083,428
# Non-trainable params: 0
# _________________________________________________________________
