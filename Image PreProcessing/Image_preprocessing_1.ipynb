# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)
test_datagen=ImageDataGenerator(rescale=1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
x_train=train_datagen.flow_from_directory(r'/content/drive/MyDrive/DATA COLLECTION/Dataset Plant Disease/Veg-dataset/Veg-dataset',target_size=(500,400),batch_size=2,class_mode='categorical')
x_test=test_datagen.flow_from_directory(r'/content/drive/MyDrive/DATA COLLECTION/Dataset Plant Disease/Veg-dataset/Veg-dataset',target_size=(450,550),batch_size=2,class_mode='categorical')
# Out:
# Found 4750 images belonging to 2 classes.
# Found 4750 images belonging to 2 classes.

# %%
x_train=train_datagen.flow_from_directory(r'/content/drive/MyDrive/DATA COLLECTION/Dataset Plant Disease/fruit-dataset/fruit-dataset',target_size=(300,200),batch_size=2,class_mode='categorical')
x_test=test_datagen.flow_from_directory(r'/content/drive/MyDrive/DATA COLLECTION/Dataset Plant Disease/fruit-dataset/fruit-dataset',target_size=(300,200),batch_size=2,class_mode='categorical')
# Out:
# Found 7120 images belonging to 2 classes.
# Found 7120 images belonging to 2 classes.
